# %% [markdown]
#   # Data Cleaning with Pandas #

# %% [markdown]
# Welcome to your introduction to Pandas and Jupyter Notebook!

# %% [markdown]
# Today we're going to learn how to read in a csv file, create a dataframe, identify different ways it may be dirty and learn some techniques for cleaning up our data set.

# %% [markdown]
# karrie.anne.kehoe@gmail.com/@karriekehoe

# %% [markdown]
# ## Getting to grips with Jupyter Notebook and Pandas

# %% [markdown]
# Jupyter Notebook is an interactive, browser based programing environment. It can be used for multiple programming languages, for writing documentation and visualising data. If you want to learn more about what Jupyter Notebook can read its documentation at http://jupyter-notebook.readthedocs.io/en/latest/notebook.html

# %% [markdown]
# Pandas is a python library, designed for statistical analysis. It's very flexible, easy to use and has a range of useful built in functions. If you want to learn more about what Pandas can do, you can read its documentation at http://pandas.pydata.org/ or browse the cook book at http://pandas.pydata.org/pandas-docs/version/0.18.1/tutorials.html

# %% [markdown]
# ### Shortcuts:
# * `esc` - takes you into command mode
# * `a` - insert cell above
# * `b` - insert cell below
# * `shift then tab` will show you the documentation for your code
# * `shift and enter` will run your cell
# * ` d d` will delete a cell

# %% [markdown]
# ### Terminology ###

# %% [markdown]
# **Dataframe** - a dataframe is a two dimensional tabular data structure with labeled axes
#
# **Series** - a series is similar to a list, array or a single column within a dataframe

# %% [markdown]
# ## Starting off

# %% [markdown]
# First we need to import Pandas our python library to do so we use the line of code below. We use 'pd' as an alias to make it easier when typing in our code.
# We are going to type
#
# `import pandas as pd`

# %%
import pandas as pd

# %% [markdown]
# Now we create a dataframe and read in our csv.
#
# `df = pd.read_csv('filepath')`

# %%
df = pd.read_csv('/Users/karrie/Desktop/DATA TRAINING/CIJ 2017/results.csv')

# %% [markdown]
# Let's look at the first ten rows of our data
#
# `df.head(10)`

# %%
df.head(10)
# Out:
#       ﻿ECRef           RegulatedEntityName RegulatedEntityType       Value  \
# 0   C0317788   The Rt Hon David Mundell MP     Regulated Donee   £2,500.00
# 1  NC0317561  UK Independence Party (UKIP)     Political Party   £2,645.00
# 2   C0317662             Liberal Democrats     Political Party   £2,858.20
# 3   C0317679             Liberal Democrats     Political Party  £20,000.00
# 4   C0317636             Liberal Democrats     Political Party   £3,050.00
# 5   C0317650             Liberal Democrats     Political Party   £5,000.00
# 6   C0317631             Liberal Democrats     Political Party   £1,500.00
# 7   C0317674             Liberal Democrats     Political Party   £3,000.00
# 8  NC0317706             Liberal Democrats     Political Party   £3,225.00
# 9   C0317629             Liberal Democrats     Political Party  £15,945.07
#
#   AcceptedDate                             AccountingUnitName  \
# 0   01/04/2017                                            NaN
# 1   31/03/2017                                      Mansfield
# 2   31/03/2017         Rugby, Nuneaton and North Warwickshire
# 3   31/03/2017  Cambridgeshire County Co-Ordinating Committee
# 4   31/03/2017                                    West Dorset
# 5   31/03/2017                          South Gloucestershire
# 6   31/03/2017                     Mid Dorset and North Poole
# 7   31/03/2017                        Twickenham and Richmond
# 8   31/03/2017                                     Colchester
# 9   31/03/2017                                  Central Party
#
#                                     DonorName AccountingUnitsAsCentralParty  \
# 0            Kirklee Property Company (2) Ltd                         False
# 1                      Arromax Structures Ltd                         False
# 2                 Rugby Lib Dem Council Group                         False
# 3                              KIRLY LIMITED                          False
# 4             Dorset CC Lib Dem Council Group                         False
# 5                          Mr Kenneth Douglas                         False
# 6                    Broadstone Lib Hall Ctte                         False
# 7  Richmond Upon Thames Lib Dem Council Group                         False
# 8               Magdalen Hall Company Limited                         False
# 9                             Mr Anthony Dunn                         False
#
#   IsSponsorship                 DonorStatus       ...       ReceivedDate  \
# 0         False                     Company       ...         01/04/2017
# 1         False                     Company       ...         31/03/2017
# 2         False  Unincorporated Association       ...         26/03/2017
# 3         False                     Company       ...         29/03/2017
# 4         False  Unincorporated Association       ...         10/03/2017
# 5         False                  Individual       ...         15/03/2017
# 6         False  Unincorporated Association       ...         29/03/2017
# 7         False  Unincorporated Association       ...         01/03/2017
# 8         False                     Company       ...         28/03/2017
# 9         False                  Individual       ...         29/03/2017
#
#   ReportedDate IsReportedPrePoll ReportingPeriodName IsBequest  IsAggregation  \
# 0   07/04/2017               NaN          April 2017     False          False
# 1   25/04/2017               NaN             Q1 2017     False          False
# 2   29/04/2017               NaN             Q1 2017     False           True
# 3   29/04/2017               NaN             Q1 2017     False          False
# 4   29/04/2017               NaN             Q1 2017     False          False
# 5   29/04/2017               NaN             Q1 2017     False          False
# 6   29/04/2017               NaN             Q1 2017     False           True
# 7   29/04/2017               NaN             Q1 2017     False           True
# 8   29/04/2017               NaN             Q1 2017     False           True
# 9   29/04/2017               NaN             Q1 2017     False          False
#
#   RegulatedEntityId AccountingUnitId DonorId CampaigningName
# 0              1491              NaN   74251             NaN
# 1                85             4928   68148             NaN
# 2                90             5276   43044             NaN
# 3                90             1849   77470             NaN
# 4                90             2376   50614             NaN
# 5                90             5141   37458             NaN
# 6                90             2116   34484             NaN
# 7                90             2346   35386             NaN
# 8                90             1892   35428             NaN
# 9                90              NaN   75232             NaN
#
# [10 rows x 27 columns]

# %% [markdown]
# Next we need to know what data types we're dealing with for each column in our dataframe
#
# `df.dtypes`

# %%
df.dtypes
# Out:
# ﻿ECRef                            object
# RegulatedEntityName               object
# RegulatedEntityType               object
# Value                             object
# AcceptedDate                      object
# AccountingUnitName                object
# DonorName                         object
# AccountingUnitsAsCentralParty       bool
# IsSponsorship                       bool
# DonorStatus                       object
# RegulatedDoneeType                object
# CompanyRegistrationNumber         object
# Postcode                          object
# DonationType                      object
# NatureOfDonation                  object
# PurposeOfVisit                   float64
# DonationAction                    object
# ReceivedDate                      object
# ReportedDate                      object
# IsReportedPrePoll                 object
# ReportingPeriodName               object
# IsBequest                           bool
# IsAggregation                       bool
# RegulatedEntityId                  int64
# AccountingUnitId                 float64
# DonorId                          float64
# CampaigningName                   object
# dtype: object

# %% [markdown]
# We use .shape to find the dimensions of our data
#
# `df.shape`

# %%
df.shape
# Out:
# (9151, 27)

# %% [markdown]
# ## Data Problems:
# * Dates are python objects and not a datetime object
# * Values are python objects and not ints or floats, so we can't perform any calculations on them
# * We need a year column, perhaps even a month column
# * There may be leading or strail spaces in our data

# %% [markdown]
# Before we change anything we're going to create a copy of our dataframe and clean that up
#
# `df2.copy()`

# %%
df2 = df.copy()

# %% [markdown]
# ## Cleaning strings
#
# We need to clean up the value column and convert it to an integer so we can count it. How do we check that it's worked?
#
# `df2['col'] = df2['col'].str.replace('£', '')`

# %%
df2['Value_clean'] = df2['Value'].str.replace('£', '')

# %%
df2.head()
# Out:
#       ﻿ECRef           RegulatedEntityName RegulatedEntityType       Value  \
# 0   C0317788   The Rt Hon David Mundell MP     Regulated Donee   £2,500.00
# 1  NC0317561  UK Independence Party (UKIP)     Political Party   £2,645.00
# 2   C0317662             Liberal Democrats     Political Party   £2,858.20
# 3   C0317679             Liberal Democrats     Political Party  £20,000.00
# 4   C0317636             Liberal Democrats     Political Party   £3,050.00
#
#   AcceptedDate                             AccountingUnitName  \
# 0   01/04/2017                                            NaN
# 1   31/03/2017                                      Mansfield
# 2   31/03/2017         Rugby, Nuneaton and North Warwickshire
# 3   31/03/2017  Cambridgeshire County Co-Ordinating Committee
# 4   31/03/2017                                    West Dorset
#
#                           DonorName AccountingUnitsAsCentralParty  \
# 0  Kirklee Property Company (2) Ltd                         False
# 1            Arromax Structures Ltd                         False
# 2       Rugby Lib Dem Council Group                         False
# 3                    KIRLY LIMITED                          False
# 4   Dorset CC Lib Dem Council Group                         False
#
#   IsSponsorship                 DonorStatus     ...     ReportedDate  \
# 0         False                     Company     ...       07/04/2017
# 1         False                     Company     ...       25/04/2017
# 2         False  Unincorporated Association     ...       29/04/2017
# 3         False                     Company     ...       29/04/2017
# 4         False  Unincorporated Association     ...       29/04/2017
#
#   IsReportedPrePoll ReportingPeriodName IsBequest IsAggregation  \
# 0               NaN          April 2017     False         False
# 1               NaN             Q1 2017     False         False
# 2               NaN             Q1 2017     False          True
# 3               NaN             Q1 2017     False         False
# 4               NaN             Q1 2017     False         False
#
#    RegulatedEntityId AccountingUnitId DonorId CampaigningName Value_clean
# 0               1491              NaN   74251             NaN    2,500.00
# 1                 85             4928   68148             NaN    2,645.00
# 2                 90             5276   43044             NaN    2,858.20
# 3                 90             1849   77470             NaN   20,000.00
# 4                 90             2376   50614             NaN    3,050.00
#
# [5 rows x 28 columns]

# %%
df2['Value_clean'] = df2['Value_clean'].str.replace(',', '')
df2['Value_clean'] = df2['Value_clean'].str.replace('.', '')

# %%
df2.head()
# Out:
#       ﻿ECRef           RegulatedEntityName RegulatedEntityType       Value  \
# 0   C0317788   The Rt Hon David Mundell MP     Regulated Donee   £2,500.00
# 1  NC0317561  UK Independence Party (UKIP)     Political Party   £2,645.00
# 2   C0317662             Liberal Democrats     Political Party   £2,858.20
# 3   C0317679             Liberal Democrats     Political Party  £20,000.00
# 4   C0317636             Liberal Democrats     Political Party   £3,050.00
#
#   AcceptedDate                             AccountingUnitName  \
# 0   01/04/2017                                            NaN
# 1   31/03/2017                                      Mansfield
# 2   31/03/2017         Rugby, Nuneaton and North Warwickshire
# 3   31/03/2017  Cambridgeshire County Co-Ordinating Committee
# 4   31/03/2017                                    West Dorset
#
#                           DonorName AccountingUnitsAsCentralParty  \
# 0  Kirklee Property Company (2) Ltd                         False
# 1            Arromax Structures Ltd                         False
# 2       Rugby Lib Dem Council Group                         False
# 3                    KIRLY LIMITED                          False
# 4   Dorset CC Lib Dem Council Group                         False
#
#   IsSponsorship                 DonorStatus     ...     ReportedDate  \
# 0         False                     Company     ...       07/04/2017
# 1         False                     Company     ...       25/04/2017
# 2         False  Unincorporated Association     ...       29/04/2017
# 3         False                     Company     ...       29/04/2017
# 4         False  Unincorporated Association     ...       29/04/2017
#
#   IsReportedPrePoll ReportingPeriodName IsBequest IsAggregation  \
# 0               NaN          April 2017     False         False
# 1               NaN             Q1 2017     False         False
# 2               NaN             Q1 2017     False          True
# 3               NaN             Q1 2017     False         False
# 4               NaN             Q1 2017     False         False
#
#    RegulatedEntityId AccountingUnitId DonorId CampaigningName Value_clean
# 0               1491              NaN   74251             NaN      250000
# 1                 85             4928   68148             NaN      264500
# 2                 90             5276   43044             NaN      285820
# 3                 90             1849   77470             NaN     2000000
# 4                 90             2376   50614             NaN      305000
#
# [5 rows x 28 columns]

# %% [markdown]
# Now check to see if that worked

# %%
df2.dtypes
# Out:
# ﻿ECRef                            object
# RegulatedEntityName               object
# RegulatedEntityType               object
# Value                             object
# AcceptedDate                      object
# AccountingUnitName                object
# DonorName                         object
# AccountingUnitsAsCentralParty       bool
# IsSponsorship                       bool
# DonorStatus                       object
# RegulatedDoneeType                object
# CompanyRegistrationNumber         object
# Postcode                          object
# DonationType                      object
# NatureOfDonation                  object
# PurposeOfVisit                   float64
# DonationAction                    object
# ReceivedDate                      object
# ReportedDate                      object
# IsReportedPrePoll                 object
# ReportingPeriodName               object
# IsBequest                           bool
# IsAggregation                       bool
# RegulatedEntityId                  int64
# AccountingUnitId                 float64
# DonorId                          float64
# CampaigningName                   object
# Value_clean                       object
# dtype: object

# %% [markdown]
# ## Changing data types
#
# Ok, no luck. We need to explicitly change the data type for the new Value clean column.
#
# `df2['Value_clean'] = pd.to_numeric(df2['Value_clean'])`

# %%
df2['Value_clean'] = pd.to_numeric(df2['Value_clean'])
df2.dtypes
# Out:
# ﻿ECRef                            object
# RegulatedEntityName               object
# RegulatedEntityType               object
# Value                             object
# AcceptedDate                      object
# AccountingUnitName                object
# DonorName                         object
# AccountingUnitsAsCentralParty       bool
# IsSponsorship                       bool
# DonorStatus                       object
# RegulatedDoneeType                object
# CompanyRegistrationNumber         object
# Postcode                          object
# DonationType                      object
# NatureOfDonation                  object
# PurposeOfVisit                   float64
# DonationAction                    object
# ReceivedDate                      object
# ReportedDate                      object
# IsReportedPrePoll                 object
# ReportingPeriodName               object
# IsBequest                           bool
# IsAggregation                       bool
# RegulatedEntityId                  int64
# AccountingUnitId                 float64
# DonorId                          float64
# CampaigningName                   object
# Value_clean                        int64
# dtype: object

# %% [markdown]
# However we need to make sure that we count our donations amount correctly. So let's divide the column by 100.

# %%
df2['Value_clean'] = df2['Value_clean']/100
df2.head()
# Out:
#       ﻿ECRef           RegulatedEntityName RegulatedEntityType       Value  \
# 0   C0317788   The Rt Hon David Mundell MP     Regulated Donee   £2,500.00
# 1  NC0317561  UK Independence Party (UKIP)     Political Party   £2,645.00
# 2   C0317662             Liberal Democrats     Political Party   £2,858.20
# 3   C0317679             Liberal Democrats     Political Party  £20,000.00
# 4   C0317636             Liberal Democrats     Political Party   £3,050.00
#
#   AcceptedDate                             AccountingUnitName  \
# 0   01/04/2017                                            NaN
# 1   31/03/2017                                      Mansfield
# 2   31/03/2017         Rugby, Nuneaton and North Warwickshire
# 3   31/03/2017  Cambridgeshire County Co-Ordinating Committee
# 4   31/03/2017                                    West Dorset
#
#                           DonorName AccountingUnitsAsCentralParty  \
# 0  Kirklee Property Company (2) Ltd                         False
# 1            Arromax Structures Ltd                         False
# 2       Rugby Lib Dem Council Group                         False
# 3                    KIRLY LIMITED                          False
# 4   Dorset CC Lib Dem Council Group                         False
#
#   IsSponsorship                 DonorStatus     ...     ReportedDate  \
# 0         False                     Company     ...       07/04/2017
# 1         False                     Company     ...       25/04/2017
# 2         False  Unincorporated Association     ...       29/04/2017
# 3         False                     Company     ...       29/04/2017
# 4         False  Unincorporated Association     ...       29/04/2017
#
#   IsReportedPrePoll ReportingPeriodName IsBequest IsAggregation  \
# 0               NaN          April 2017     False         False
# 1               NaN             Q1 2017     False         False
# 2               NaN             Q1 2017     False          True
# 3               NaN             Q1 2017     False         False
# 4               NaN             Q1 2017     False         False
#
#    RegulatedEntityId AccountingUnitId DonorId CampaigningName Value_clean
# 0               1491              NaN   74251             NaN      2500.0
# 1                 85             4928   68148             NaN      2645.0
# 2                 90             5276   43044             NaN      2858.2
# 3                 90             1849   77470             NaN     20000.0
# 4                 90             2376   50614             NaN      3050.0
#
# [5 rows x 28 columns]

# %% [markdown]
# ## Dropping and re-naming columns
#
# Let's clean up our dataframe a bit by dropping the original Value column - the 1 is the index, so we're saying it's the column with the value Value in the first row
#
# `df2 = df2.drop('Value', 1)`

# %%
df2 = df2.drop('Value', 1)
df2.head()
# Out:
#       ﻿ECRef           RegulatedEntityName RegulatedEntityType AcceptedDate  \
# 0   C0317788   The Rt Hon David Mundell MP     Regulated Donee   01/04/2017
# 1  NC0317561  UK Independence Party (UKIP)     Political Party   31/03/2017
# 2   C0317662             Liberal Democrats     Political Party   31/03/2017
# 3   C0317679             Liberal Democrats     Political Party   31/03/2017
# 4   C0317636             Liberal Democrats     Political Party   31/03/2017
#
#                               AccountingUnitName  \
# 0                                            NaN
# 1                                      Mansfield
# 2         Rugby, Nuneaton and North Warwickshire
# 3  Cambridgeshire County Co-Ordinating Committee
# 4                                    West Dorset
#
#                           DonorName AccountingUnitsAsCentralParty  \
# 0  Kirklee Property Company (2) Ltd                         False
# 1            Arromax Structures Ltd                         False
# 2       Rugby Lib Dem Council Group                         False
# 3                    KIRLY LIMITED                          False
# 4   Dorset CC Lib Dem Council Group                         False
#
#   IsSponsorship                 DonorStatus         RegulatedDoneeType  \
# 0         False                     Company  MP - Member of Parliament
# 1         False                     Company                        NaN
# 2         False  Unincorporated Association                        NaN
# 3         False                     Company                        NaN
# 4         False  Unincorporated Association                        NaN
#
#       ...     ReportedDate IsReportedPrePoll ReportingPeriodName IsBequest  \
# 0     ...       07/04/2017               NaN          April 2017     False
# 1     ...       25/04/2017               NaN             Q1 2017     False
# 2     ...       29/04/2017               NaN             Q1 2017     False
# 3     ...       29/04/2017               NaN             Q1 2017     False
# 4     ...       29/04/2017               NaN             Q1 2017     False
#
#    IsAggregation RegulatedEntityId AccountingUnitId DonorId CampaigningName  \
# 0          False              1491              NaN   74251             NaN
# 1          False                85             4928   68148             NaN
# 2           True                90             5276   43044             NaN
# 3          False                90             1849   77470             NaN
# 4          False                90             2376   50614             NaN
#
#   Value_clean
# 0      2500.0
# 1      2645.0
# 2      2858.2
# 3     20000.0
# 4      3050.0
#
# [5 rows x 27 columns]

# %% [markdown]
# Now that's gone, let's rename the Value clean column
#
# `df2 = df2.rename(columns={'old_name': 'new_name'})`

# %%
df2 = df2.rename(columns={'Value_clean': 'Value'})
df2.head()
# Out:
#       ﻿ECRef           RegulatedEntityName RegulatedEntityType AcceptedDate  \
# 0   C0317788   The Rt Hon David Mundell MP     Regulated Donee   01/04/2017
# 1  NC0317561  UK Independence Party (UKIP)     Political Party   31/03/2017
# 2   C0317662             Liberal Democrats     Political Party   31/03/2017
# 3   C0317679             Liberal Democrats     Political Party   31/03/2017
# 4   C0317636             Liberal Democrats     Political Party   31/03/2017
#
#                               AccountingUnitName  \
# 0                                            NaN
# 1                                      Mansfield
# 2         Rugby, Nuneaton and North Warwickshire
# 3  Cambridgeshire County Co-Ordinating Committee
# 4                                    West Dorset
#
#                           DonorName AccountingUnitsAsCentralParty  \
# 0  Kirklee Property Company (2) Ltd                         False
# 1            Arromax Structures Ltd                         False
# 2       Rugby Lib Dem Council Group                         False
# 3                    KIRLY LIMITED                          False
# 4   Dorset CC Lib Dem Council Group                         False
#
#   IsSponsorship                 DonorStatus         RegulatedDoneeType  \
# 0         False                     Company  MP - Member of Parliament
# 1         False                     Company                        NaN
# 2         False  Unincorporated Association                        NaN
# 3         False                     Company                        NaN
# 4         False  Unincorporated Association                        NaN
#
#     ...    ReportedDate IsReportedPrePoll ReportingPeriodName IsBequest  \
# 0   ...      07/04/2017               NaN          April 2017     False
# 1   ...      25/04/2017               NaN             Q1 2017     False
# 2   ...      29/04/2017               NaN             Q1 2017     False
# 3   ...      29/04/2017               NaN             Q1 2017     False
# 4   ...      29/04/2017               NaN             Q1 2017     False
#
#    IsAggregation RegulatedEntityId AccountingUnitId DonorId CampaigningName  \
# 0          False              1491              NaN   74251             NaN
# 1          False                85             4928   68148             NaN
# 2           True                90             5276   43044             NaN
# 3          False                90             1849   77470             NaN
# 4          False                90             2376   50614             NaN
#
#      Value
# 0   2500.0
# 1   2645.0
# 2   2858.2
# 3  20000.0
# 4   3050.0
#
# [5 rows x 27 columns]

# %% [markdown]
# Let's make sure there aren't any trail or leading spaces in the column names, if so this could cause havoc
#
# `df2.columns`

# %%
df2.columns
# Out:
# Index([u'﻿ECRef', u'RegulatedEntityName', u'RegulatedEntityType',
#        u'AcceptedDate', u'AccountingUnitName', u'DonorName',
#        u'AccountingUnitsAsCentralParty', u'IsSponsorship', u'DonorStatus',
#        u'RegulatedDoneeType', u'CompanyRegistrationNumber', u'Postcode',
#        u'DonationType', u'NatureOfDonation', u'PurposeOfVisit',
#        u'DonationAction', u'ReceivedDate', u'ReportedDate',
#        u'IsReportedPrePoll', u'ReportingPeriodName', u'IsBequest',
#        u'IsAggregation', u'RegulatedEntityId', u'AccountingUnitId', u'DonorId',
#        u'CampaigningName', u'Value'],
#       dtype='object')

# %% [markdown]
# All good, but maybe there are some in the donor names.
#
# `df2['column'].unique()`

# %%
df2['DonorName'].unique()
# Out:
# array(['Kirklee Property Company (2) Ltd', 'Arromax Structures Ltd',
#        'Rugby Lib Dem Council Group', ..., ' Anthony Clarke',
#        'Professor Peter F Saville', 'Mrs Jelena Guadagnini'], dtype=object)

# %% [markdown]
# Yup just like I thought, there is a leading space in Anthony Clarke, we need to fix that. First though we need to make sure that the DonorName is a column of strings, if there are any numeric names in there it'll confuse python and we won't be able to manipulate the column
#
# `df2['column'] = df2['column'].astype(str)`

# %%
df2['DonorName'] = df2['DonorName'].astype(str)

# %% [markdown]
# Ok now we're going to strip out any of those trail spaces
#
# `df2['column']=df2['column'].map(str.strip)`

# %%
df2['DonorName_clean']=df2['DonorName'].map(str.strip)

# %% [markdown]
# Did that work?
#
# `df2[column].unique()`

# %%
df2['DonorName_clean'].unique()
# Out:
# array(['Kirklee Property Company (2) Ltd', 'Arromax Structures Ltd',
#        'Rugby Lib Dem Council Group', ..., 'Anthony Clarke',
#        'Professor Peter F Saville', 'Mrs Jelena Guadagnini'], dtype=object)

# %% [markdown]
# ## Dates and Years
#
# Ok, the reporting periods are pretty messy, so let's create a new column with the year value in there. We can extract that from one of the date columns. To do that we need to import the new library called datetime
#
# `import datetime`

# %%
import datetime

# %% [markdown]
# Now we're going to strip the year from the accepted date and insert the value in a new column called 'Year'
#
# `df2['YEAR'] = pd.DatetimeIndex(df2['AcceptedDate']).year`

# %%
df2['YEAR'] = pd.DatetimeIndex(df2['AcceptedDate']).year

# %% [markdown]
# Did that work? If so let's try do the same for the month value, same formula as year

# %%
df2.head()
# Out:
#       ﻿ECRef           RegulatedEntityName RegulatedEntityType AcceptedDate  \
# 0   C0317788   The Rt Hon David Mundell MP     Regulated Donee   01/04/2017
# 1  NC0317561  UK Independence Party (UKIP)     Political Party   31/03/2017
# 2   C0317662             Liberal Democrats     Political Party   31/03/2017
# 3   C0317679             Liberal Democrats     Political Party   31/03/2017
# 4   C0317636             Liberal Democrats     Political Party   31/03/2017
#
#                               AccountingUnitName  \
# 0                                            NaN
# 1                                      Mansfield
# 2         Rugby, Nuneaton and North Warwickshire
# 3  Cambridgeshire County Co-Ordinating Committee
# 4                                    West Dorset
#
#                           DonorName AccountingUnitsAsCentralParty  \
# 0  Kirklee Property Company (2) Ltd                         False
# 1            Arromax Structures Ltd                         False
# 2       Rugby Lib Dem Council Group                         False
# 3                    KIRLY LIMITED                          False
# 4   Dorset CC Lib Dem Council Group                         False
#
#   IsSponsorship                 DonorStatus         RegulatedDoneeType  ...   \
# 0         False                     Company  MP - Member of Parliament  ...
# 1         False                     Company                        NaN  ...
# 2         False  Unincorporated Association                        NaN  ...
# 3         False                     Company                        NaN  ...
# 4         False  Unincorporated Association                        NaN  ...
#
#   ReportingPeriodName IsBequest IsAggregation RegulatedEntityId  \
# 0          April 2017     False         False              1491
# 1             Q1 2017     False         False                85
# 2             Q1 2017     False          True                90
# 3             Q1 2017     False         False                90
# 4             Q1 2017     False         False                90
#
#    AccountingUnitId DonorId CampaigningName    Value  \
# 0               NaN   74251             NaN   2500.0
# 1              4928   68148             NaN   2645.0
# 2              5276   43044             NaN   2858.2
# 3              1849   77470             NaN  20000.0
# 4              2376   50614             NaN   3050.0
#
#                     DonorName_clean  YEAR
# 0  Kirklee Property Company (2) Ltd  2017
# 1            Arromax Structures Ltd  2017
# 2       Rugby Lib Dem Council Group  2017
# 3                     KIRLY LIMITED  2017
# 4   Dorset CC Lib Dem Council Group  2017
#
# [5 rows x 29 columns]

# %%
df2['MONTH'] = pd.DatetimeIndex(df2['AcceptedDate']).month

# %%
df2.head()
# Out:
#       ﻿ECRef           RegulatedEntityName RegulatedEntityType AcceptedDate  \
# 0   C0317788   The Rt Hon David Mundell MP     Regulated Donee   01/04/2017
# 1  NC0317561  UK Independence Party (UKIP)     Political Party   31/03/2017
# 2   C0317662             Liberal Democrats     Political Party   31/03/2017
# 3   C0317679             Liberal Democrats     Political Party   31/03/2017
# 4   C0317636             Liberal Democrats     Political Party   31/03/2017
#
#                               AccountingUnitName  \
# 0                                            NaN
# 1                                      Mansfield
# 2         Rugby, Nuneaton and North Warwickshire
# 3  Cambridgeshire County Co-Ordinating Committee
# 4                                    West Dorset
#
#                           DonorName AccountingUnitsAsCentralParty  \
# 0  Kirklee Property Company (2) Ltd                         False
# 1            Arromax Structures Ltd                         False
# 2       Rugby Lib Dem Council Group                         False
# 3                    KIRLY LIMITED                          False
# 4   Dorset CC Lib Dem Council Group                         False
#
#   IsSponsorship                 DonorStatus         RegulatedDoneeType  ...   \
# 0         False                     Company  MP - Member of Parliament  ...
# 1         False                     Company                        NaN  ...
# 2         False  Unincorporated Association                        NaN  ...
# 3         False                     Company                        NaN  ...
# 4         False  Unincorporated Association                        NaN  ...
#
#   IsBequest IsAggregation RegulatedEntityId AccountingUnitId  DonorId  \
# 0     False         False              1491              NaN    74251
# 1     False         False                85             4928    68148
# 2     False          True                90             5276    43044
# 3     False         False                90             1849    77470
# 4     False         False                90             2376    50614
#
#   CampaigningName    Value                   DonorName_clean  YEAR MONTH
# 0             NaN   2500.0  Kirklee Property Company (2) Ltd  2017     1
# 1             NaN   2645.0            Arromax Structures Ltd  2017     3
# 2             NaN   2858.2       Rugby Lib Dem Council Group  2017     3
# 3             NaN  20000.0                     KIRLY LIMITED  2017     3
# 4             NaN   3050.0   Dorset CC Lib Dem Council Group  2017     3
#
# [5 rows x 30 columns]

# %% [markdown]
# ## Shrinking dataframes
#
# Ok finally let's get rid of some of the columns and make our dataframe a more manageable size
#
# To do this we need a list of column names again

# %%
df2.columns
# Out:
# Index([u'﻿ECRef', u'RegulatedEntityName', u'RegulatedEntityType',
#        u'AcceptedDate', u'AccountingUnitName', u'DonorName',
#        u'AccountingUnitsAsCentralParty', u'IsSponsorship', u'DonorStatus',
#        u'RegulatedDoneeType', u'CompanyRegistrationNumber', u'Postcode',
#        u'DonationType', u'NatureOfDonation', u'PurposeOfVisit',
#        u'DonationAction', u'ReceivedDate', u'ReportedDate',
#        u'IsReportedPrePoll', u'ReportingPeriodName', u'IsBequest',
#        u'IsAggregation', u'RegulatedEntityId', u'AccountingUnitId', u'DonorId',
#        u'CampaigningName', u'Value', u'DonorName_clean', u'YEAR', u'MONTH'],
#       dtype='object')

# %% [markdown]
# Alright let's figure what we need and shrink the dataframe
#
# `df2 = df2[['RegulatedEntityName', 'AcceptedDate', 'DonorName_clean', 'DonorStatus', 'YEAR', 'Value', 'RegulatedEntityType', 'DonorId', 'CampaigningName']]`

# %%
df2 = df2[['RegulatedEntityName', 'AcceptedDate', 'DonorName_clean', 'DonorStatus', 'YEAR', 'Value', 'RegulatedEntityType', 'DonorId', 'CampaigningName']]

# %%
df2.head()
# Out:
#             RegulatedEntityName AcceptedDate  \
# 0   The Rt Hon David Mundell MP   01/04/2017
# 1  UK Independence Party (UKIP)   31/03/2017
# 2             Liberal Democrats   31/03/2017
# 3             Liberal Democrats   31/03/2017
# 4             Liberal Democrats   31/03/2017
#
#                     DonorName_clean                 DonorStatus  YEAR  \
# 0  Kirklee Property Company (2) Ltd                     Company  2017
# 1            Arromax Structures Ltd                     Company  2017
# 2       Rugby Lib Dem Council Group  Unincorporated Association  2017
# 3                     KIRLY LIMITED                     Company  2017
# 4   Dorset CC Lib Dem Council Group  Unincorporated Association  2017
#
#      Value RegulatedEntityType  DonorId CampaigningName
# 0   2500.0     Regulated Donee    74251             NaN
# 1   2645.0     Political Party    68148             NaN
# 2   2858.2     Political Party    43044             NaN
# 3  20000.0     Political Party    77470             NaN
# 4   3050.0     Political Party    50614             NaN

# %% [markdown]
# ## Saving our data
#
# Ok finally let's save our clean for the next class
#
# `df2.to_csv('clean_data.csv', encoding='utf8')`

# %%
df2.to_csv('clean_data.csv', encoding='utf8')
